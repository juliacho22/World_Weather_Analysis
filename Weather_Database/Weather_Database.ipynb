# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)
# Create a list for holding the cities.
from citipy import citipy
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Import the requests library, API key, and datetime module from the datetime library.
import requests
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=105b7864620dd447e068fa2e035fde71

# %%
city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url).json()
city_weather["weather"][0]["description"]
# Out:
# 'scattered clouds'

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | katsuura
# Processing Record 9 of Set 1 | constitucion
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | diego de almagro
# Processing Record 12 of Set 1 | sao sebastiao
# Processing Record 13 of Set 1 | havre-saint-pierre
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | purranque
# Processing Record 16 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | poso
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | ponferrada
# Processing Record 21 of Set 1 | praia da vitoria
# Processing Record 22 of Set 1 | port lincoln
# Processing Record 23 of Set 1 | auki
# Processing Record 24 of Set 1 | pangnirtung
# Processing Record 25 of Set 1 | russkaya polyana
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | portland
# Processing Record 28 of Set 1 | mezen
# Processing Record 29 of Set 1 | nanchang
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | tshikapa
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | kulhudhuffushi
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | iqaluit
# Processing Record 40 of Set 1 | pecos
# Processing Record 41 of Set 1 | nishihara
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | show low
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | maridi
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | benjamin constant
# Processing Record 48 of Set 1 | ferme-neuve
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | qostanay
# Processing Record 1 of Set 2 | babayurt
# Processing Record 2 of Set 2 | kampot
# Processing Record 3 of Set 2 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | karasjok
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 2 | yagodnoye
# Processing Record 13 of Set 2 | shirokiy
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 2 | salalah
# Processing Record 17 of Set 2 | honningsvag
# Processing Record 18 of Set 2 | padang
# Processing Record 19 of Set 2 | marsh harbour
# Processing Record 20 of Set 2 | lavrentiya
# Processing Record 21 of Set 2 | santa ana
# Processing Record 22 of Set 2 | chigorodo
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | vostok
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | souillac
# Processing Record 28 of Set 2 | rudbar
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | mehamn
# Processing Record 31 of Set 2 | russell
# Processing Record 32 of Set 2 | ancud
# Processing Record 33 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 2 | muros
# Processing Record 35 of Set 2 | pevek
# Processing Record 36 of Set 2 | bhopal
# Processing Record 37 of Set 2 | leo
# Processing Record 38 of Set 2 | helong
# Processing Record 39 of Set 2 | olavarria
# Processing Record 40 of Set 2 | zhangjiakou
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | nanortalik
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | santa cruz
# Processing Record 45 of Set 2 | kandi
# Processing Record 46 of Set 2 | asau
# Processing Record 47 of Set 2 | moindou
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | hede
# Processing Record 50 of Set 2 | nanning
# Processing Record 1 of Set 3 | manali
# Processing Record 2 of Set 3 | port hardy
# Processing Record 3 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | yumen
# Processing Record 6 of Set 3 | ostrovnoy
# Processing Record 7 of Set 3 | najran
# Processing Record 8 of Set 3 | lovozero
# Processing Record 9 of Set 3 | gwanda
# Processing Record 10 of Set 3 | laguna
# Processing Record 11 of Set 3 | huilong
# Processing Record 12 of Set 3 | haines junction
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | takoradi
# Processing Record 15 of Set 3 | umm kaddadah
# Processing Record 16 of Set 3 | veraval
# Processing Record 17 of Set 3 | aklavik
# Processing Record 18 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | hun
# Processing Record 20 of Set 3 | jalu
# Processing Record 21 of Set 3 | adrar
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | mitsamiouli
# Processing Record 25 of Set 3 | verkhoyansk
# Processing Record 26 of Set 3 | esperance
# Processing Record 27 of Set 3 | uvalde
# Processing Record 28 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 3 | kapaa
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | pervoye maya
# Processing Record 32 of Set 3 | zhezkazgan
# Processing Record 33 of Set 3 | rocha
# Processing Record 34 of Set 3 | olinda
# Processing Record 35 of Set 3 | cidreira
# Processing Record 36 of Set 3 | bara
# Processing Record 37 of Set 3 | hasaki
# Processing Record 38 of Set 3 | goundam
# Processing Record 39 of Set 3 | abu dhabi
# Processing Record 40 of Set 3 | kahului
# Processing Record 41 of Set 3 | apucarana
# Processing Record 42 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 3 | roebourne
# Processing Record 44 of Set 3 | parnamirim
# Processing Record 45 of Set 3 | mosquera
# Processing Record 46 of Set 3 | atuona
# Processing Record 47 of Set 3 | hermanus
# Processing Record 48 of Set 3 | nanzhang
# Processing Record 49 of Set 3 | marrakesh
# Processing Record 50 of Set 3 | brownsville
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | champasak
# Processing Record 3 of Set 4 | camana
# Processing Record 4 of Set 4 | vardo
# Processing Record 5 of Set 4 | darhan
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | lata
# Processing Record 8 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 4 | yerbogachen
# Processing Record 10 of Set 4 | yarada
# Processing Record 11 of Set 4 | cherskiy
# Processing Record 12 of Set 4 | alofi
# Processing Record 13 of Set 4 | saldanha
# Processing Record 14 of Set 4 | kununurra
# Processing Record 15 of Set 4 | nikolskoye
# Processing Record 16 of Set 4 | fortuna
# Processing Record 17 of Set 4 | zyryanka
# Processing Record 18 of Set 4 | moldova sulita
# Processing Record 19 of Set 4 | kinsale
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | usinsk
# Processing Record 22 of Set 4 | lebedinyy
# Processing Record 23 of Set 4 | port blair
# Processing Record 24 of Set 4 | tibati
# Processing Record 25 of Set 4 | lima
# Processing Record 26 of Set 4 | fiumicino
# Processing Record 27 of Set 4 | tura
# Processing Record 28 of Set 4 | cabo san lucas
# Processing Record 29 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 4 | tomatlan
# Processing Record 31 of Set 4 | saint-philippe
# Processing Record 32 of Set 4 | te anau
# Processing Record 33 of Set 4 | bandarbeyla
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | cape town
# Processing Record 37 of Set 4 | zarate
# Processing Record 38 of Set 4 | aksu
# Processing Record 39 of Set 4 | punta cardon
# Processing Record 40 of Set 4 | jining
# Processing Record 41 of Set 4 | bambous virieux
# Processing Record 42 of Set 4 | kushima
# Processing Record 43 of Set 4 | ponta do sol
# Processing Record 44 of Set 4 | khao wong
# Processing Record 45 of Set 4 | poum
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | zheleznodorozhnyy
# Processing Record 48 of Set 4 | roald
# Processing Record 49 of Set 4 | tuktoyaktuk
# Processing Record 50 of Set 4 | la rioja
# Processing Record 1 of Set 5 | pombia
# Processing Record 2 of Set 5 | boende
# Processing Record 3 of Set 5 | labuhan
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | san patricio
# Processing Record 6 of Set 5 | skjervoy
# Processing Record 7 of Set 5 | cayenne
# Processing Record 8 of Set 5 | mvangue
# Processing Record 9 of Set 5 | taixing
# Processing Record 10 of Set 5 | guerrero negro
# Processing Record 11 of Set 5 | georgetown
# Processing Record 12 of Set 5 | hami
# Processing Record 13 of Set 5 | huarmey
# Processing Record 14 of Set 5 | krasnogorskoye
# Processing Record 15 of Set 5 | pochutla
# Processing Record 16 of Set 5 | guspini
# Processing Record 17 of Set 5 | trinidad
# Processing Record 18 of Set 5 | anshun
# Processing Record 19 of Set 5 | khomutovo
# Processing Record 20 of Set 5 | bac lieu
# Processing Record 21 of Set 5 | geraldton
# Processing Record 22 of Set 5 | domoni
# Processing Record 23 of Set 5 | puerto cabezas
# Processing Record 24 of Set 5 | dakar
# Processing Record 25 of Set 5 | casper
# Processing Record 26 of Set 5 | isangel
# Processing Record 27 of Set 5 | hithadhoo
# Processing Record 28 of Set 5 | dasoguz
# Processing Record 29 of Set 5 | san cristobal
# Processing Record 30 of Set 5 | angoram
# Processing Record 31 of Set 5 | daru
# Processing Record 32 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 5 | meadow lake
# Processing Record 34 of Set 5 | bengkulu
# Processing Record 35 of Set 5 | sao filipe
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | canakkale
# Processing Record 38 of Set 5 | rundu
# Processing Record 39 of Set 5 | teeli
# Processing Record 40 of Set 5 | chuy
# Processing Record 41 of Set 5 | bredasdorp
# Processing Record 42 of Set 5 | broome
# Processing Record 43 of Set 5 | sistranda
# Processing Record 44 of Set 5 | lagoa
# Processing Record 45 of Set 5 | kieta
# Processing Record 46 of Set 5 | grand gaube
# Processing Record 47 of Set 5 | conceicao da barra
# Processing Record 48 of Set 5 | kalmunai
# Processing Record 49 of Set 5 | sindou
# Processing Record 50 of Set 5 | talnakh
# Processing Record 1 of Set 6 | castro
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | leningradskiy
# Processing Record 4 of Set 6 | jamestown
# Processing Record 5 of Set 6 | saint george
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | wonthaggi
# Processing Record 8 of Set 6 | alyangula
# Processing Record 9 of Set 6 | coolum beach
# Processing Record 10 of Set 6 | lircay
# Processing Record 11 of Set 6 | berezovyy
# Processing Record 12 of Set 6 | taoudenni
# Processing Record 13 of Set 6 | watertown
# Processing Record 14 of Set 6 | tevriz
# Processing Record 15 of Set 6 | axim
# Processing Record 16 of Set 6 | san policarpo
# Processing Record 17 of Set 6 | pisco
# Processing Record 18 of Set 6 | ulaangom
# Processing Record 19 of Set 6 | severo-kurilsk
# Processing Record 20 of Set 6 | sorland
# Processing Record 21 of Set 6 | sulangan
# Processing Record 22 of Set 6 | brae
# Processing Record 23 of Set 6 | groningen
# Processing Record 24 of Set 6 | lompoc
# Processing Record 25 of Set 6 | shache
# Processing Record 26 of Set 6 | chiang kham
# Processing Record 27 of Set 6 | vestmanna
# Processing Record 28 of Set 6 | ust-ilimsk
# Processing Record 29 of Set 6 | novyye gorki
# Processing Record 30 of Set 6 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 31 of Set 6 | perevolotskiy
# Processing Record 32 of Set 6 | kebemer
# City not found. Skipping...
# Processing Record 33 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 34 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 6 | sindand
# City not found. Skipping...
# Processing Record 36 of Set 6 | salto
# Processing Record 37 of Set 6 | abnub
# Processing Record 38 of Set 6 | north platte
# Processing Record 39 of Set 6 | nome
# Processing Record 40 of Set 6 | virginia beach
# Processing Record 41 of Set 6 | iralaya
# Processing Record 42 of Set 6 | adiake
# Processing Record 43 of Set 6 | richards bay
# Processing Record 44 of Set 6 | zeya
# Processing Record 45 of Set 6 | mawlaik
# Processing Record 46 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 6 | pemangkat
# Processing Record 48 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 49 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 6 | clyde river
# Processing Record 1 of Set 7 | koumac
# Processing Record 2 of Set 7 | dawei
# Processing Record 3 of Set 7 | dapaong
# Processing Record 4 of Set 7 | ureki
# Processing Record 5 of Set 7 | quartz hill
# Processing Record 6 of Set 7 | san matias
# Processing Record 7 of Set 7 | tautira
# Processing Record 8 of Set 7 | rjukan
# Processing Record 9 of Set 7 | lulea
# Processing Record 10 of Set 7 | ca mau
# Processing Record 11 of Set 7 | nouadhibou
# Processing Record 12 of Set 7 | olafsvik
# Processing Record 13 of Set 7 | cangzhou
# Processing Record 14 of Set 7 | sioux lookout
# Processing Record 15 of Set 7 | longyearbyen
# Processing Record 16 of Set 7 | camacha
# Processing Record 17 of Set 7 | baker city
# Processing Record 18 of Set 7 | revelstoke
# Processing Record 19 of Set 7 | luderitz
# Processing Record 20 of Set 7 | vanavara
# Processing Record 21 of Set 7 | lar gerd
# City not found. Skipping...
# Processing Record 22 of Set 7 | menongue
# Processing Record 23 of Set 7 | tiarei
# Processing Record 24 of Set 7 | saint anthony
# Processing Record 25 of Set 7 | sanary-sur-mer
# Processing Record 26 of Set 7 | ixtapa
# Processing Record 27 of Set 7 | lodja
# Processing Record 28 of Set 7 | brokopondo
# Processing Record 29 of Set 7 | gamba
# Processing Record 30 of Set 7 | belyy yar
# Processing Record 31 of Set 7 | klaksvik
# Processing Record 32 of Set 7 | maceio
# Processing Record 33 of Set 7 | manzil tamim
# City not found. Skipping...
# Processing Record 34 of Set 7 | tokur
# Processing Record 35 of Set 7 | eshowe
# Processing Record 36 of Set 7 | helena
# Processing Record 37 of Set 7 | slave lake
# Processing Record 38 of Set 7 | ukiah
# Processing Record 39 of Set 7 | bouca
# Processing Record 40 of Set 7 | vestmannaeyjar
# Processing Record 41 of Set 7 | sobolevo
# Processing Record 42 of Set 7 | provideniya
# Processing Record 43 of Set 7 | tagusao
# Processing Record 44 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 46 of Set 7 | garissa
# Processing Record 47 of Set 7 | gimli
# Processing Record 48 of Set 7 | mahebourg
# Processing Record 49 of Set 7 | pacific grove
# Processing Record 50 of Set 7 | lincoln
# Processing Record 1 of Set 8 | kemijarvi
# Processing Record 2 of Set 8 | kavieng
# Processing Record 3 of Set 8 | sept-iles
# Processing Record 4 of Set 8 | praya
# Processing Record 5 of Set 8 | tigzirt
# Processing Record 6 of Set 8 | broken hill
# Processing Record 7 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 8 | erie
# Processing Record 9 of Set 8 | fairbanks
# Processing Record 10 of Set 8 | langsa
# Processing Record 11 of Set 8 | la romana
# Processing Record 12 of Set 8 | ponta delgada
# Processing Record 13 of Set 8 | zyryanovsk
# Processing Record 14 of Set 8 | yulara
# Processing Record 15 of Set 8 | kamaishi
# Processing Record 16 of Set 8 | shetpe
# Processing Record 17 of Set 8 | loukhi
# Processing Record 18 of Set 8 | ketchikan
# Processing Record 19 of Set 8 | stephenville
# Processing Record 20 of Set 8 | lagos
# Processing Record 21 of Set 8 | nagykanizsa
# Processing Record 22 of Set 8 | gorontalo
# Processing Record 23 of Set 8 | savannah bight
# Processing Record 24 of Set 8 | vila velha
# Processing Record 25 of Set 8 | phuket
# Processing Record 26 of Set 8 | tubuala
# Processing Record 27 of Set 8 | caravelas
# Processing Record 28 of Set 8 | taonan
# Processing Record 29 of Set 8 | opuwo
# Processing Record 30 of Set 8 | acapulco
# Processing Record 31 of Set 8 | mount isa
# Processing Record 32 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 8 | yar-sale
# Processing Record 34 of Set 8 | marsa matruh
# Processing Record 35 of Set 8 | palmerston
# Processing Record 36 of Set 8 | port hawkesbury
# Processing Record 37 of Set 8 | voh
# Processing Record 38 of Set 8 | sur
# Processing Record 39 of Set 8 | atambua
# Processing Record 40 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 8 | araripe
# Processing Record 42 of Set 8 | bilma
# Processing Record 43 of Set 8 | naze
# Processing Record 44 of Set 8 | natal
# Processing Record 45 of Set 8 | owando
# Processing Record 46 of Set 8 | atbasar
# Processing Record 47 of Set 8 | ryotsu
# Processing Record 48 of Set 8 | saint-denis
# Processing Record 49 of Set 8 | payakumbuh
# Processing Record 50 of Set 8 | mayya
# Processing Record 1 of Set 9 | uddevalla
# Processing Record 2 of Set 9 | namtsy
# Processing Record 3 of Set 9 | puerto narino
# Processing Record 4 of Set 9 | namatanai
# Processing Record 5 of Set 9 | havoysund
# Processing Record 6 of Set 9 | hambantota
# Processing Record 7 of Set 9 | otjiwarongo
# Processing Record 8 of Set 9 | linxia
# Processing Record 9 of Set 9 | agva
# City not found. Skipping...
# Processing Record 10 of Set 9 | rio gallegos
# Processing Record 11 of Set 9 | hamilton
# Processing Record 12 of Set 9 | les cayes
# Processing Record 13 of Set 9 | udachnyy
# Processing Record 14 of Set 9 | umm lajj
# Processing Record 15 of Set 9 | quatre cocos
# Processing Record 16 of Set 9 | bolobo
# Processing Record 17 of Set 9 | lere
# Processing Record 18 of Set 9 | banda aceh
# Processing Record 19 of Set 9 | monteagudo
# Processing Record 20 of Set 9 | cedar city
# Processing Record 21 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 22 of Set 9 | havre
# Processing Record 23 of Set 9 | palu
# Processing Record 24 of Set 9 | olga
# Processing Record 25 of Set 9 | praia
# Processing Record 26 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 9 | igarka
# Processing Record 28 of Set 9 | mapiripan
# Processing Record 29 of Set 9 | kiama
# Processing Record 30 of Set 9 | verkhnechusovskiye gorodki
# Processing Record 31 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 32 of Set 9 | amapa
# Processing Record 33 of Set 9 | byron bay
# Processing Record 34 of Set 9 | cuenca
# Processing Record 35 of Set 9 | dunedin
# Processing Record 36 of Set 9 | bodden town
# Processing Record 37 of Set 9 | bathsheba
# Processing Record 38 of Set 9 | goderich
# Processing Record 39 of Set 9 | touros
# Processing Record 40 of Set 9 | aksha
# Processing Record 41 of Set 9 | zhangye
# Processing Record 42 of Set 9 | san nicolas
# Processing Record 43 of Set 9 | fort nelson
# Processing Record 44 of Set 9 | half moon bay
# Processing Record 45 of Set 9 | beisfjord
# Processing Record 46 of Set 9 | chibombo
# Processing Record 47 of Set 9 | stabat
# Processing Record 48 of Set 9 | hobyo
# Processing Record 49 of Set 9 | kirkenaer
# Processing Record 50 of Set 9 | pozo de gamboa
# City not found. Skipping...
# Processing Record 1 of Set 10 | san jose
# Processing Record 2 of Set 10 | la baule-escoublac
# Processing Record 3 of Set 10 | loa janan
# Processing Record 4 of Set 10 | pareora
# Processing Record 5 of Set 10 | vredendal
# Processing Record 6 of Set 10 | esmeraldas
# Processing Record 7 of Set 10 | severodvinsk
# Processing Record 8 of Set 10 | neiafu
# Processing Record 9 of Set 10 | ayorou
# Processing Record 10 of Set 10 | victoria
# Processing Record 11 of Set 10 | tolaga bay
# Processing Record 12 of Set 10 | torrington
# Processing Record 13 of Set 10 | lasa
# Processing Record 14 of Set 10 | mata
# Processing Record 15 of Set 10 | raudeberg
# Processing Record 16 of Set 10 | maragogi
# Processing Record 17 of Set 10 | srednekolymsk
# Processing Record 18 of Set 10 | bahia blanca
# Processing Record 19 of Set 10 | svetlogorsk
# Processing Record 20 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 22 of Set 10 | biak
# Processing Record 23 of Set 10 | saint-augustin
# Processing Record 24 of Set 10 | bonoua
# Processing Record 25 of Set 10 | kourou
# Processing Record 26 of Set 10 | hibbing
# Processing Record 27 of Set 10 | tokmak
# Processing Record 28 of Set 10 | lensk
# Processing Record 29 of Set 10 | sabang
# Processing Record 30 of Set 10 | balsta
# Processing Record 31 of Set 10 | saint-joseph
# Processing Record 32 of Set 10 | lakes entrance
# Processing Record 33 of Set 10 | lumeje
# Processing Record 34 of Set 10 | sola
# Processing Record 35 of Set 10 | port-gentil
# Processing Record 36 of Set 10 | malibu
# Processing Record 37 of Set 10 | korla
# Processing Record 38 of Set 10 | boshkengash
# Processing Record 39 of Set 10 | roma
# Processing Record 40 of Set 10 | hofn
# Processing Record 41 of Set 10 | bay roberts
# Processing Record 42 of Set 10 | rouvroy
# Processing Record 43 of Set 10 | erzin
# Processing Record 44 of Set 10 | hrinova
# Processing Record 45 of Set 10 | djibo
# Processing Record 46 of Set 10 | xichang
# Processing Record 47 of Set 10 | teknaf
# Processing Record 48 of Set 10 | nunspeet
# Processing Record 49 of Set 10 | eyl
# Processing Record 50 of Set 10 | shimoda
# Processing Record 1 of Set 11 | arona
# Processing Record 2 of Set 11 | bhigvan
# Processing Record 3 of Set 11 | bend
# Processing Record 4 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 11 | vieques
# Processing Record 6 of Set 11 | komsomolskiy
# Processing Record 7 of Set 11 | dingwall
# Processing Record 8 of Set 11 | batsfjord
# Processing Record 9 of Set 11 | bayir
# Processing Record 10 of Set 11 | ilhabela
# Processing Record 11 of Set 11 | anloga
# Processing Record 12 of Set 11 | sal rei
# Processing Record 13 of Set 11 | samarai
# Processing Record 14 of Set 11 | khokhlovo
# Processing Record 15 of Set 11 | christchurch
# Processing Record 16 of Set 11 | hokitika
# Processing Record 17 of Set 11 | dwarka
# Processing Record 18 of Set 11 | qui nhon
# Processing Record 19 of Set 11 | neuquen
# Processing Record 20 of Set 11 | kargat
# Processing Record 21 of Set 11 | zhaotong
# Processing Record 22 of Set 11 | portel
# Processing Record 23 of Set 11 | bahia de caraquez
# Processing Record 24 of Set 11 | quartucciu
# Processing Record 25 of Set 11 | pangkalanbuun
# Processing Record 26 of Set 11 | genhe
# Processing Record 27 of Set 11 | barsovo
# Processing Record 28 of Set 11 | valdivia
# Processing Record 29 of Set 11 | mattru
# Processing Record 30 of Set 11 | kachug
# Processing Record 31 of Set 11 | khani
# Processing Record 32 of Set 11 | santa cruz del norte
# Processing Record 33 of Set 11 | tambun
# Processing Record 34 of Set 11 | evensk
# Processing Record 35 of Set 11 | verkhniye tatyshly
# Processing Record 36 of Set 11 | barhi
# Processing Record 37 of Set 11 | biloxi
# Processing Record 38 of Set 11 | dubbo
# Processing Record 39 of Set 11 | tostamaa
# City not found. Skipping...
# Processing Record 40 of Set 11 | new ulm
# Processing Record 41 of Set 11 | ust-nera
# Processing Record 42 of Set 11 | san carlos de bariloche
# Processing Record 43 of Set 11 | sinnamary
# Processing Record 44 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 45 of Set 11 | havelock
# Processing Record 46 of Set 11 | cururupu
# Processing Record 47 of Set 11 | presque isle
# Processing Record 48 of Set 11 | dawlatabad
# Processing Record 49 of Set 11 | riyadh
# Processing Record 50 of Set 11 | comodoro rivadavia
# Processing Record 1 of Set 12 | phangnga
# Processing Record 2 of Set 12 | point fortin
# Processing Record 3 of Set 12 | ola
# Processing Record 4 of Set 12 | carbonia
# Processing Record 5 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 12 | dalinghe
# City not found. Skipping...
# Processing Record 7 of Set 12 | freeport
# Processing Record 8 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 9 of Set 12 | soyo
# Processing Record 10 of Set 12 | sao raimundo das mangabeiras
# Processing Record 11 of Set 12 | kyakhta
# Processing Record 12 of Set 12 | rio grande
# Processing Record 13 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 12 | senanga
# Processing Record 15 of Set 12 | el doncello
# Processing Record 16 of Set 12 | valparaiso
# Processing Record 17 of Set 12 | birao
# Processing Record 18 of Set 12 | logansport
# Processing Record 19 of Set 12 | ajdabiya
# Processing Record 20 of Set 12 | aripuana
# Processing Record 21 of Set 12 | smidovich
# Processing Record 22 of Set 12 | ust-tsilma
# Processing Record 23 of Set 12 | paka
# Processing Record 24 of Set 12 | nabire
# Processing Record 25 of Set 12 | gweru
# Processing Record 26 of Set 12 | ahipara
# Processing Record 27 of Set 12 | mount gambier
# Processing Record 28 of Set 12 | anori
# Processing Record 29 of Set 12 | jati
# Processing Record 30 of Set 12 | bardiyah
# Processing Record 31 of Set 12 | ashford
# Processing Record 32 of Set 12 | verkhnyaya sinyachikha
# Processing Record 33 of Set 12 | san ramon
# Processing Record 34 of Set 12 | narrabri
# Processing Record 35 of Set 12 | husavik
# Processing Record 36 of Set 12 | prince rupert
# Processing Record 37 of Set 12 | saintes
# Processing Record 38 of Set 12 | san andres
# Processing Record 39 of Set 12 | ormara
# Processing Record 40 of Set 12 | liwale
# Processing Record 41 of Set 12 | platanos
# Processing Record 42 of Set 12 | grand-santi
# Processing Record 43 of Set 12 | asosa
# Processing Record 44 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 45 of Set 12 | mecca
# Processing Record 46 of Set 12 | omboue
# Processing Record 47 of Set 12 | mandera
# Processing Record 48 of Set 12 | sao gabriel da cachoeira
# Processing Record 49 of Set 12 | ayan
# Processing Record 50 of Set 12 | linqiong
# Processing Record 1 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 13 | kawalu
# Processing Record 3 of Set 13 | roncesvalles
# Processing Record 4 of Set 13 | herat
# Processing Record 5 of Set 13 | richmond
# Processing Record 6 of Set 13 | kaura namoda
# Processing Record 7 of Set 13 | palmer
# Processing Record 8 of Set 13 | puerto del rosario
# Processing Record 9 of Set 13 | cabra
# Processing Record 10 of Set 13 | yuzhnyy
# Processing Record 11 of Set 13 | primo tapia
# Processing Record 12 of Set 13 | rantepao
# Processing Record 13 of Set 13 | aras
# Processing Record 14 of Set 13 | merauke
# Processing Record 15 of Set 13 | shcholkine
# City not found. Skipping...
# Processing Record 16 of Set 13 | jeremie
# Processing Record 17 of Set 13 | lubbock
# Processing Record 18 of Set 13 | purpe
# Processing Record 19 of Set 13 | namibe
# Processing Record 20 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 13 | buchanan
# Processing Record 22 of Set 13 | nadym
# Processing Record 23 of Set 13 | ucluelet
# Processing Record 24 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 13 | sokolo
# Processing Record 26 of Set 13 | zhigansk
# Processing Record 27 of Set 13 | yaan
# Processing Record 28 of Set 13 | kuching
# Processing Record 29 of Set 13 | ulladulla
# Processing Record 30 of Set 13 | kavaratti
# Processing Record 31 of Set 13 | banff
# Processing Record 32 of Set 13 | savinskiy
# Processing Record 33 of Set 13 | obala
# Processing Record 34 of Set 13 | jinchang
# Processing Record 35 of Set 13 | vao
# Processing Record 36 of Set 13 | kamina
# Processing Record 37 of Set 13 | mayumba
# Processing Record 38 of Set 13 | bjornevatn
# Processing Record 39 of Set 13 | kishanpur
# Processing Record 40 of Set 13 | saint-georges
# Processing Record 41 of Set 13 | oksfjord
# Processing Record 42 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 13 | bull savanna
# Processing Record 44 of Set 13 | tucuma
# Processing Record 45 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 13 | ende
# Processing Record 47 of Set 13 | price
# Processing Record 48 of Set 13 | benguela
# Processing Record 49 of Set 13 | tocopilla
# Processing Record 50 of Set 13 | karak
# Processing Record 1 of Set 14 | sirfa
# City not found. Skipping...
# Processing Record 2 of Set 14 | pio xii
# Processing Record 3 of Set 14 | wana
# Processing Record 4 of Set 14 | sinazongwe
# Processing Record 5 of Set 14 | mogadishu
# Processing Record 6 of Set 14 | leh
# Processing Record 7 of Set 14 | sangar
# Processing Record 8 of Set 14 | dunda
# Processing Record 9 of Set 14 | diu
# Processing Record 10 of Set 14 | yatou
# Processing Record 11 of Set 14 | trairi
# Processing Record 12 of Set 14 | faya
# Processing Record 13 of Set 14 | vilyuysk
# Processing Record 14 of Set 14 | ivanava
# Processing Record 15 of Set 14 | jiazi
# Processing Record 16 of Set 14 | novoseleznevo
# Processing Record 17 of Set 14 | elat
# Processing Record 18 of Set 14 | hailar
# Processing Record 19 of Set 14 | norman wells
# Processing Record 20 of Set 14 | netolice
# Processing Record 21 of Set 14 | bhachau
# Processing Record 22 of Set 14 | svetlaya
# Processing Record 23 of Set 14 | itoman
# Processing Record 24 of Set 14 | tamale
# Processing Record 25 of Set 14 | mayo
# Processing Record 26 of Set 14 | hendijan
# City not found. Skipping...
# Processing Record 27 of Set 14 | ewa beach
# Processing Record 28 of Set 14 | kota bahru
# Processing Record 29 of Set 14 | roblin
# Processing Record 30 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 31 of Set 14 | akureyri
# Processing Record 32 of Set 14 | kasangulu
# Processing Record 33 of Set 14 | carutapera
# Processing Record 34 of Set 14 | puma
# Processing Record 35 of Set 14 | mudgee
# Processing Record 36 of Set 14 | talcahuano
# Processing Record 37 of Set 14 | kholmogory
# Processing Record 38 of Set 14 | gat
# Processing Record 39 of Set 14 | severnoye
# Processing Record 40 of Set 14 | egvekinot
# Processing Record 41 of Set 14 | chicama
# Processing Record 42 of Set 14 | mlowo
# Processing Record 43 of Set 14 | gizo
# Processing Record 44 of Set 14 | missoula
# Processing Record 45 of Set 14 | bosaso
# Processing Record 46 of Set 14 | pundaguitan
# Processing Record 47 of Set 14 | vangaindrano
# Processing Record 48 of Set 14 | hovd
# Processing Record 49 of Set 14 | istra
# Processing Record 50 of Set 14 | lopsmarka
# Processing Record 1 of Set 15 | midland
# Processing Record 2 of Set 15 | suicheng
# Processing Record 3 of Set 15 | perth
# Processing Record 4 of Set 15 | mendi
# Processing Record 5 of Set 15 | kapit
# Processing Record 6 of Set 15 | aswan
# Processing Record 7 of Set 15 | pervomayskoye
# Processing Record 8 of Set 15 | ubauro
# Processing Record 9 of Set 15 | ischia
# Processing Record 10 of Set 15 | hefei
# Processing Record 11 of Set 15 | port said
# Processing Record 12 of Set 15 | palora
# Processing Record 13 of Set 15 | boueni
# Processing Record 14 of Set 15 | meybod
# Processing Record 15 of Set 15 | dhidhdhoo
# Processing Record 16 of Set 15 | sangueya
# Processing Record 17 of Set 15 | nuuk
# Processing Record 18 of Set 15 | nsanje
# Processing Record 19 of Set 15 | phichit
# Processing Record 20 of Set 15 | lorengau
# Processing Record 21 of Set 15 | matthews
# Processing Record 22 of Set 15 | muroto
# Processing Record 23 of Set 15 | mbandaka
# Processing Record 24 of Set 15 | mamallapuram
# Processing Record 25 of Set 15 | college
# Processing Record 26 of Set 15 | berbera
# Processing Record 27 of Set 15 | illapel
# Processing Record 28 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 29 of Set 15 | krasnyy chikoy
# Processing Record 30 of Set 15 | pula
# Processing Record 31 of Set 15 | bhindar
# Processing Record 32 of Set 15 | nisia floresta
# Processing Record 33 of Set 15 | tres arroyos
# Processing Record 34 of Set 15 | berlevag
# Processing Record 35 of Set 15 | kharp
# Processing Record 36 of Set 15 | pontianak
# Processing Record 37 of Set 15 | denpasar
# Processing Record 38 of Set 15 | mandalgovi
# Processing Record 39 of Set 15 | lhuntshi
# City not found. Skipping...
# Processing Record 40 of Set 15 | betsiamites
# Processing Record 41 of Set 15 | coquimbo
# Processing Record 42 of Set 15 | milingimbi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0       East London      ZA -33.0153   27.9116     54.48        57
# 1           Qaanaaq      GL  77.4840  -69.3632     32.56        82
# 2             Vaini      TO -21.2000 -175.2000     75.36        73
# 3       Yellowknife      CA  62.4560 -114.3525     63.12        63
# 4              Hilo      US  19.7297 -155.0900     86.29        63
# 5       Port Alfred      ZA -33.5906   26.8910     54.45        71
# 6          Katsuura      JP  35.1333  140.3000     71.71        82
# 7      Constitucion      CL -35.3333  -72.4167     54.63        86
# 8           Rikitea      PF -23.1203 -134.9692     75.27        77
# 9  Diego De Almagro      CL -26.3667  -70.0500     57.00        70
#
#    Cloudiness  Wind Speed Current Description
# 0           4        7.36           clear sky
# 1          55        1.83       broken clouds
# 2          40        2.30    scattered clouds
# 3          40        4.61    scattered clouds
# 4           1       11.50           clear sky
# 5           1        8.90           clear sky
# 6          95       13.04     overcast clouds
# 7         100        9.86     overcast clouds
# 8          75       13.47       broken clouds
# 9           0        1.28           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
